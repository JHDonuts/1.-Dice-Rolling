# %%
## import the libraries

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
## load the earthquake dataset
df = pd.read_csv("all_month.csv")
df.head()
# Out:
#                        time   latitude   longitude    depth   mag magType  \
# 0  2023-02-27T02:06:06.435Z  63.198500 -149.375600   73.300  1.60      ml
# 1  2023-02-27T01:51:31.620Z  38.834499 -122.818169    1.520  0.71      md
# 2  2023-02-27T01:35:49.082Z  17.390100  147.530000   10.000  4.90      mb
# 3  2023-02-27T01:31:15.500Z -32.907300 -178.867400   45.006  5.10      mb
# 4  2023-02-27T01:27:10.987Z  58.643600 -154.314300  101.600  2.00      ml
#
#     nst    gap     dmin   rms  ...                   updated  \
# 0   NaN    NaN      NaN  0.78  ...  2023-02-27T02:08:44.101Z
# 1  14.0   61.0  0.01276  0.01  ...  2023-02-27T02:08:14.941Z
# 2  48.0  149.0  4.56800  0.66  ...  2023-02-27T02:18:44.040Z
# 3  45.0  153.0  3.72400  0.96  ...  2023-02-27T02:03:50.040Z
# 4   NaN    NaN      NaN  0.62  ...  2023-02-27T01:29:44.672Z
#
#                            place        type horizontalError depthError  \
# 0   30 km SW of Cantwell, Alaska  earthquake             NaN      0.600
# ...

# %%
## information on the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10631 entries, 0 to 10630
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             10631 non-null  object
#  1   latitude         10631 non-null  float64
#  2   longitude        10631 non-null  float64
#  3   depth            10631 non-null  float64
#  4   mag              10631 non-null  float64
#  5   magType          10631 non-null  object
#  6   nst              7555 non-null   float64
#  7   gap              7555 non-null   float64
#  8   dmin             5652 non-null   float64
#  9   rms              10631 non-null  float64
#  10  net              10631 non-null  object
#  11  id               10631 non-null  object
#  12  updated          10631 non-null  object
#  13  place            10631 non-null  object
#  14  type             10631 non-null  object
#  15  horizontalError  7130 non-null   float64
# ...

# %%
df.describe()
# Out:
#            latitude     longitude         depth           mag          nst  \
# count  10631.000000  10631.000000  10631.000000  10631.000000  7555.000000
# mean      43.513831   -118.878475     24.346168      1.592451    23.436532
# std       18.277479     64.882920     51.897892      1.284354    25.648415
# min      -59.372600   -179.968900     -3.500000     -1.230000     0.000000
# 25%       35.950083   -154.047400      2.730000      0.800000     8.000000
# 50%       40.136100   -122.877335      8.040000      1.310000    16.000000
# 75%       58.263667   -116.809000     20.275000      2.000000    30.000000
# max       86.154600    179.996000    639.011000      7.800000   886.000000
#
#                gap         dmin           rms  horizontalError    depthError  \
# count  7555.000000  5652.000000  10631.000000      7130.000000  10631.000000
# mean    120.145961     0.589957      0.311148         1.655162      1.802138
# ...

# %%
## checking fo missing values
df.isnull().sum()
# Out:
# time                  0
# latitude              0
# longitude             0
# depth                 0
# mag                   0
# magType               0
# nst                3076
# gap                3076
# dmin               4979
# rms                   0
# net                   0
# id                    0
# updated               0
# place                 0
# type                  0
# horizontalError    3501
# depthError            0
# magError           3110
# magNst             3089
# status                0
# locationSource        0
# magSource             0
# dtype: int64

# %%
## plot histogram
df.hist(bins =10, figsize=(10,10))
plt.show()

# %% [markdown]
# Form the histogram, you can observe that the earthquakes happen to occur in a certain region of the world. Earthquakes seem to be more common in the positive latitude and the negative longtitude.

# %%
## plot boxplot
df.boxplot(figsize=(20,30))
plt.show()

# %%
## plot magnitude vs depth
plt.figure(figsize = (10, 7 ))
plt.scatter(
    x = df['mag'],
    y= df['depth'])
plt.xlabel("magnitude")
plt.ylabel("depth")
plt.title("Comparing magnitude and depth")
plt.show()

# %%
## plot magnitude vs location source
plt.figure(figsize = (11,4))
plt. scatter(
    x = df["mag"],
    y = df["locationSource"])
plt.xlabel("magnitude")
plt.ylabel("location source")
plt.title("Magnitude vs location source")
plt.show()

# %%
## scatter plot with mag, lat and long

x = df["latitude"]
y = df["longitude"]
z = df["mag"]

fig = plt.figure()
ax = np.array([fig.add_subplot(1,1,1, projection='3d')])

ax[0].scatter(x,y,z)
ax[0].set_title('comparing magnitude with the latitude and longtitude of the earthquakes')


plt.show()

# %% [markdown]
# The scatter plot graph shows that there is a  cluster of points in the region of high latitude and low longitude, whether it was a high magnitude or not. however, a very high concentrate of high magnitude earthqwuakes did seem to occur in the regions of high longitutdes.

# %%
# simpler graph showing the location of the earthquakes


plt.figure(figsize = (11,4))
plt. scatter(
    x = df["longitude"],
    y = df["latitude"])
plt.xlabel("longitude")
plt.ylabel("latitude")
plt.title("Location of the earthquakes in relation to the longitutde and latitude")
plt.show()

# %%
##plot correlation matrix
corr_mat = df.corr()
corr_mat
# Out:
# C:\Users\44790\AppData\Local\Temp\ipykernel_19052\838129088.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_mat = df.corr()
#                  latitude  longitude     depth       mag       nst       gap  \
# latitude         1.000000  -0.510955 -0.197947 -0.506246 -0.322528  0.184981
# longitude       -0.510955   1.000000  0.114115  0.641414  0.434780 -0.219127
# depth           -0.197947   0.114115  1.000000  0.345073  0.193513 -0.048192
# mag             -0.506246   0.641414  0.345073  1.000000  0.600384 -0.192367
# nst             -0.322528   0.434780  0.193513  0.600384  1.000000 -0.379797
# gap              0.184981  -0.219127 -0.048192 -0.192367 -0.379797  1.000000
# dmin            -0.459456   0.395354  0.248670  0.478700  0.226041  0.005985
# ...

# %%
# heatmap

plt.figure(figsize=(10,10))
sns.heatmap(corr_mat, annot=True)
plt.title("correlation plot")
plt.show()

# %% [markdown]
# In a heatmap, we plot to see the relationship betweeen the two variables, the closer they are to either 1 or -1, they are more correlated to each other. Vice-versa, if the data is closer to 0 than it is to +/-1, that means they are not correlated to each other.
