# %%
yes = ["Yes", "yes", "Y", "y"]
no = ["No", "no", "N", "n"]

print("""

Welcome to the TEXT ADVENTURE GAME

You must enter your house and find all the household chores in each of the rooms to have a great day!

Will you enter your house? (Yes/No)

Note: You only have 3 rooms, bedroom, living room and a kitchen.

""")

ans1 = input(">>")

if ans1 in yes:
    print("\nYou open your stiff wooden door and arive at the entrance of your house, where would you like to go? Would you enter the first room on the right? (Yes/No\n")

    ans2 = input(">>")
    if ans2 in yes:
        print("""
              \nYou found the Kitchen, and realise you left the stove on. You switch this off preventing a fire.
              
              Now you return to the entrance again.
              
              Will you go to the room on the left this time? (Yes/No)\n
              """)
        
        ans4 = input (">>")
        
        if ans4 in yes:
            print("\nYou have entered the bedroom where you made you bed and folded the clean clothes. Now will you enter the final room? (Yes/No)\n")
            
            ans5 = input (">>")
            
            if ans5 in yes:
                print("""
                      \nYou have entered the final room, the living room where there are the chinese takeaway boxes to throw away.
                      
                      CONGRATULATIONS
                      
                      YOU HAVE FOUND ALL THE MESS IN THE HOUSE, YOU WILL HAVE AN AWESOME DAY.
                      
                      WELL DONE!!!
                      """)
            
            elif ans5 in no:
                print ("You have failed to enter all the rooms. GAME OVER")
            
            else:
                print("Wrong input. Au revoir")
                
        elif ans4 in no:
            print("You have not attempted to enter all the rooms so you have failed the mission. GAME OVER")
        else:
            print("You have inpupted the wrong input. Au revoir.")    
            
            
    elif ans2 in no:
        print("\nWill you go to the room on the left? (Yes/No)")
        
        ans3 = input(">>")
        
        if ans3 in yes:
            print("""
                  \nYou have entered the bedroom, you make your bed and fold the clothes.
                  
                  You return to the entrance and will you enter the room on the right?(Yes/No)\n
                  """)
            
            ans6 = input (">>")
            
            if ans6 in yes:
                print("""
                      \nYou have entered the Kitchen, your leftover curry is burning. You siwtch off the stove and stop any chance of a fire.
                      
                      Will you now enter the last room? (Yes/No)\n
                      """)
                
                ans7 = input(">>")
                
                if ans7 in yes:
                    print("""
                          \nCONGRATULATIONS!!!
                          
                          You have entered the final room, the living room, you have found the left over chinese takeaway that if was left any longer would have started to mould and stink the house.
                          
                          You have found all the mess in the house and you will havea clean house.
                          
                          You will have an awesome day.
                          
                          GOODBYE!!!
                          """)
                elif ans7 in no:
                    print("\nGAME OVER, You have failed to enter all the rooms, you will have rats swarming around teh house very soon. GOOD LUCK")
                else:
                    print("\nWrong input. Au revoir.")
            
            elif ans6 in no:
                print("""
                      \nWill you enter the other room instead? (Yes/No)\n                      
                      """)
                ans8 = input (">>")
                
                if ans8 in yes:
                    print("""
                          \nYou have entered the living room.
                          
                          There is takeaway food that needs to be cleaned up.
                          
                          Will you enter the final room? (Yes/No)\n
                          """)
                    ans9 = input(">>")
                    if ans9 in yes:
                        print("""
                              \nWELL DONE!
                              
                              You have found the kitchen and the stove was still on burning the curry.
                              
                              CONGRATULATIONS, you found all the mess.
                              
                              You will have an awesome day. GOODBYE. 
                              
                              """)
                    elif ans9 in no:
                        print("\nYou have failed to find all the mess, youre house will likely to burn down now. GAME OVER")
                    else:
                        print("\nWRONG input. Au revoir")
                
                elif ans8 in no:
                    print("\nYou have not attempted to enter all the rooms...GAME OVER")
                else:
                    print("\nWrong input. Au revoir")
                
        
        elif ans3 in no:
            print("\nYou have not attempted to enter all the rooms and you have left the house to burn down, GAME OVER")



elif ans1 in no:
    print("\nYou did not enter the house, so you have not cleaned your house, you have failed and the house will burn down. GAME OVER")
    
else:
    print("\nYou have the wrong input. Au revoir!")
# Out:
# Welcome to the TEXT ADVENTURE GAME
#
# You must enter your house and find all the household chores in each of the rooms to have a great day!
#
# Will you enter your house? (Yes/No)
#
# Note: You only have 3 rooms, bedroom, living room and a kitchen.
#
#
#
# You open your stiff wooden door and arive at the entrance of your house, where would you like to go? Would you enter the first room on the right? (Yes/No
#
#
# Will you go to the room on the left? (Yes/No)
#
#
# You have entered the bedroom, you make your bed and fold the clothes.
#
#                   You return to the entrance and will you enter the room on the right?(Yes/No)
#
#
#
#
# Will you enter the other room instead? (Yes/No)
#
#
#
# You have not attempted to enter all the rooms...GAME OVER
